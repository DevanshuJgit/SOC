# %%
import pandas as pd

# %%
df = pd.read_csv('Housing.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df2 = pd.read_csv('Housing_2.csv', names=['price','area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus'])
df2.head()
# Out:
#              price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# my_index     price  area  bedrooms  bathrooms  stories  mainroad  guestroom
# 1         13300000  7420         4          2        3         1          0
# 2         12250000  8960         4          4        4         1          0
# 3         12250000  9960         3          2        2         1          0
# 4         12215000  7500         4          2        2         1          0
#
#           basement  hotwaterheating  airconditioning  parking  prefarea  \
# my_index  basement  hotwaterheating  airconditioning  parking  prefarea
# 1                0                0                1        2         1
# 2                0                0                1        3         0
# 3                1                0                0        2         1
# 4                1                0                1        3         1
#
#           furnishingstatus
# my_index  furnishingstatus
# ...

# %%
df3 = pd.read_csv('Housing_3.csv',index_col='my_index' )
df3.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df3 = pd.read_csv('Housing_2.csv',index_col='my_index' )
#       2 df3.head()
#
# File c:\Users\DJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df4 = pd.read_csv('Housing_4.csv', header=1)
df4.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df5 = pd.read_csv('Housing.csv', usecols=['price','area','bathrooms'])
df5.head()
# Out:
#       price  area  bathrooms
# 0  13300000  7420          2
# 1  12250000  8960          4
# 2  12250000  9960          2
# 3  12215000  7500          2
# 4  11410000  7420          1

# %%
df6 = pd.read_csv('Housing.csv', skiprows=[1,2])
df6.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  12250000  9960         3          2        2         1          0
# 1  12215000  7500         4          2        2         1          0
# 2  11410000  7420         4          1        2         1          1
# 3  10850000  7500         3          3        1         1          0
# 4  10150000  8580         4          3        4         1          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         1                0                0        2         1
# 1         1                0                1        3         1
# 2         1                0                1        2         0
# 3         1                0                1        2         1
# 4         0                0                1        2         1
#
#   furnishingstatus
# 0   semi-furnished
# 1        furnished
# 2        furnished
# 3   semi-furnished
# 4   semi-furnished

# %%
df7 = pd.read_csv('Housing.csv', nrows=2)
df7.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished

# %%
df8 = pd.read_csv('Housing.csv',dtype={'mainroad':float})
df8.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0          0
# 1  12250000  8960         4          4        4       1.0          0
# 2  12250000  9960         3          2        2       1.0          0
# 3  12215000  7500         4          2        2       1.0          0
# 4  11410000  7420         4          1        2       1.0          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
# df6 = pd.read_csv('Housing.csv', parse_dates=['date'])
# df6.head()

# %%
def imput(n):
    if n=='furnished':
        return 1
    else:
        return 0

# %%
df9 = pd.read_csv('Housing.csv', converters={'furnishingstatus':imput})
df9.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 1

# %%
df10 = pd.read_csv('Housing_4.csv', na_values=['furnished'])
df10.head()
# Out:
#           1     2         3          4        5         6          7  \
# 0     price  area  bedrooms  bathrooms  stories  mainroad  guestroom
# 1  13300000  7420         4          2        3         1          0
# 2  12250000  8960         4          4        4         1          0
# 3  12250000  9960         3          2        2         1          0
# 4  12215000  7500         4          2        2         1          0
#
#           8                9               10       11        12  \
# 0  basement  hotwaterheating  airconditioning  parking  prefarea
# 1         0                0                1        2         1
# 2         0                0                1        3         0
# 3         1                0                0        2         1
# 4         1                0                1        3         1
#
#                  13
# 0  furnishingstatus
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
dfs = pd.read_csv('Housing.csv', chunksize=200)
for chunks in dfs:
    print(chunks.shape)
# Out:
# (200, 13)
# (200, 13)
# (145, 13)
